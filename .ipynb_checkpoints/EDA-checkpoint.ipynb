# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %config InlineBackend.figure_format ='retina'

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer provided  min_salary  \
# count  781.000000   781.000000  781.000000         781.000000  781.000000
# mean     3.665301  1807.766965    0.002561           0.012804   85.576697
# std      0.949959   537.512325    0.050572           0.112500   27.848269
# min     -1.000000    -1.000000    0.000000           0.000000    3.000000
# 25%      3.400000  1937.000000    0.000000           0.000000   68.000000
# 50%      3.800000  1972.000000    0.000000           0.000000   84.000000
# 75%      4.100000  1993.000000    0.000000           0.000000  104.000000
# max      5.000000  2020.000000    1.000000           1.000000  219.000000
#
#        max_salary  avg_salary  hq_same_state  company_age      python  \
# count  781.000000  781.000000     781.000000   781.000000  781.000000
# mean   107.380026   96.478361       0.385403    49.126761    0.142125
# std     29.482501   28.005685       0.487002    41.309781    0.349403
# min     20.000000   11.500000       0.000000    -1.000000    0.000000
# 25%     88.000000   77.000000       0.000000    20.000000    0.000000
# 50%    107.000000   95.500000       0.000000    39.000000    0.000000
# 75%    125.000000  113.000000       1.000000    65.000000    0.000000
# max    219.000000  219.000000       1.000000   201.000000    1.000000
#
#            matlab         cpp         sql        java         dsp       power  \
# count  781.000000  781.000000  781.000000  781.000000  781.000000  781.000000
# mean     0.092190    0.120359    0.056338    0.046095    0.066581    0.495519
# std      0.289479    0.325589    0.230721    0.209825    0.249455    0.500300
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        Embedded_System          ML      desc_len  Num_Competitors
# count       781.000000  781.000000    781.000000       781.000000
# mean          0.124200    0.020487   3998.476312         1.055058
# std           0.330021    0.141748   1714.242751         1.337158
# min           0.000000    0.000000    863.000000         0.000000
# 25%           0.000000    0.000000   2847.000000         0.000000
# 50%           0.000000    0.000000   3785.000000         0.000000
# 75%           0.000000    0.000000   4962.000000         3.000000
# max           1.000000    1.000000  16036.000000         4.000000

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.company_age.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column = ['avg_salary'])

# %%
df[ ['company_age', 'avg_salary', 'Rating', 'desc_len', 'Num_Competitors'] ].corr()
# Out:
#                  company_age  avg_salary    Rating  desc_len  Num_Competitors
# company_age         1.000000   -0.076461  0.056347  0.137320         0.245548
# avg_salary         -0.076461    1.000000  0.135630  0.040125         0.132486
# Rating              0.056347    0.135630  1.000000  0.053409         0.050860
# desc_len            0.137320    0.040125  0.053409  1.000000        -0.019834
# Num_Competitors     0.245548    0.132486  0.050860 -0.019834         1.000000

# %%
cmap = sns.diverging_palette(220,10, as_cmap =True)
sns.heatmap(df[['company_age', 'avg_salary', 'Rating', 'desc_len', 'Num_Competitors']].corr(), vmax = .3, center =0, cmap=cmap, 
               square = True, linewidths=0.5, cbar_kws={"shrink": .5} )

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'hq_same_state', 'company_age', 'python',
#        'matlab', 'cpp', 'sql', 'java', 'dsp', 'power', 'Embedded_System', 'ML',
#        'seniority', 'desc_len', 'Num_Competitors'],
#       dtype='object')

# %%
df_cat = df[[ 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'job_state', 'hq_same_state']]
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print('graph for %s: total = %d' % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Size: total = 9
# graph for Type of ownership: total = 10
# graph for Industry: total = 44
# graph for Sector: total = 17
# graph for Revenue: total = 14
# graph for job_state: total = 44
# graph for hq_same_state: total = 2

# %%
df_cat = df[[ 'python','matlab', 'cpp', 'dsp', 'power', 'Embedded_System', 'ML',]]
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()[:20]
    print('graph for %s: total = %d' % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for python: total = 2
# graph for matlab: total = 2
# graph for cpp: total = 2
# graph for dsp: total = 2
# graph for power: total = 2
# graph for Embedded_System: total = 2
# graph for ML: total = 2

# %%
df_cat = df[['Location', 'Headquarters','company_txt']]
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()[:20]
    print('graph for %s: total = %d' % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for company_txt: total = 20

# %%
df.seniority.value_counts()
# Out:
# na        486
# senior    278
# junior     10
# entry       7
# Name: seniority, dtype: int64

# %%
pd.pivot_table(df, index =['seniority'], values ='avg_salary')[:20]
# Out:
#            avg_salary
# seniority
# entry       74.642857
# junior      92.350000
# na          88.979630
# senior     110.285971

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index =['job_state', 'seniority'], values= 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending = False)
# Out:
#                      avg_salary
# job_state seniority
#  WV       na                  1
#  WI       senior              3
#           na                  9
#  WA       senior              7
#           na                  7
#  VT       na                  1
#  VA       na                 30
#           junior              3
#           senior             25
#  UT       senior              1
#           na                  7
#           junior              7
#  TX       senior             10
#           na                 16
#  TN       senior              1
#           na                  6
#  SC       senior              2
#           na                  4
#  RI       senior              1
#           na                  3
#  PA       na                  9
#           entry               2
#           senior              4
#  OR       senior              6
#           na                 14
#  OK       senior              1
#           na                  1
#  OH       na                 12
#           senior              7
#  NY       na                 22
#           entry               2
#           senior             14
#  NV       na                  1
#  NJ       senior              2
#           na                  9
#  NH       senior              3
#  NE       na                  1
#  ND       senior              1
#  NC       na                 10
#           senior              2
#  MT       entry               1
#  MS       na                  4
#  MO       senior              3
#           na                  6
#  MN       senior              2
#           na                  9
#  MI       senior             24
#           na                 24
#  MD       na                 36
#           senior             24
#  MA       na                 31
#           senior             19
#  LA       senior              8
#           na                  3
#  KY       na                  7
#  KS       na                  1
#  IN       senior              1
#           na                  9
#  IL       senior              9
#           na                  9
#  IA       na                  3
#           senior              1
#  GA       na                 12
#           senior              4
#  FL       senior              3
#           na                  9
#  DE       senior              1
#           na                  1
#  DC       senior             10
#           na                  2
#  CT       senior              5
#           na                 17
#  CO       senior              8
#           na                 15
#  CA       senior             49
#           na                106
#           entry               2
#  AZ       senior              9
#           na                 10
#  AL       senior              8
#           na                  5
#  AK       na                  4

# %%
# rating, industry, sector, revenue, number of comp, hourly, employer provided, python, dsp, cpp, ml, desc_len, Type of ownership

# %%
df_pivots = df [[ 'job_state', 'Rating', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 
                 'python','matlab', 'cpp', 'dsp', 'power', 'Embedded_System', 'ML',
                 'Num_Competitors', 'avg_salary'  ]]

# %%
for i in df_pivots.columns[:-1]:
    print(pd.pivot_table(df_pivots, index = i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
    print('')
    print('')
    print('')
# Out:
#            avg_salary
# job_state
#  MD        114.691667
#  CA        113.819108
#  DC        112.416667
#  VA        104.818966
#  NH        104.500000
#  IL        103.138889
#  LA         98.681818
#  ND         98.500000
#  RI         98.125000
#  CO         96.673913
#  MN         96.090909
#  MA         95.810000
#  WA         95.714286
#  OR         94.900000
#  OK         93.500000
#  AK         93.125000
#  TX         91.480769
#  OH         91.368421
#  AL         90.538462
#  NY         90.039474
#  MO         89.555556
#  MI         88.479167
#  FL         87.791667
#  NV         87.500000
#  DE         86.750000
#  AZ         85.473684
#  PA         82.900000
#  WV         81.500000
#  UT         81.400000
#  IA         81.375000
#  NJ         80.500000
#  CT         80.045455
#  SC         79.666667
#  WI         77.833333
#  MS         76.250000
#  MT         74.000000
#  IN         71.750000
#  KS         70.000000
#  NE         66.500000
#  NC         66.375000
#  GA         65.625000
#  VT         62.000000
#  TN         61.071429
#  KY         50.214286
#
#
#
#         avg_salary
# Rating
#  4.5    109.433333
#  3.9    104.733333
#  3.8    102.762712
#  3.7    102.739437
#  3.4    101.685185
#  5.0    101.562500
#  3.5     99.621429
#  3.2     99.500000
#  4.0     97.520833
#  4.7     96.972222
#  2.6     96.916667
#  4.8     96.500000
#  4.4     96.413793
#  2.2     95.500000
#  2.4     94.700000
#  3.6     94.241667
#  3.0     92.611111
#  2.9     91.166667
#  4.2     90.475000
#  2.5     89.625000
#  4.3     89.029412
#  2.0     87.000000
#  3.1     84.763158
#  4.1     84.640000
#  4.6     83.761905
#  3.3     80.787879
#  4.9     80.500000
#  2.7     79.333333
#  2.8     79.305556
# -1.0     76.833333
#  2.3     71.000000
#  1.9     69.500000
#
#
#
#                                 avg_salary
# Type of ownership
# Government                      123.272727
# -1                              109.000000
# Company - Public                108.793436
# Private Practice / Firm          98.166667
# Subsidiary or Business Segment   97.045455
# Company - Private                88.632648
# Nonprofit Organization           88.173913
# Other Organization               86.250000
# Unknown                          77.807692
# Franchise                        77.500000
#
#
#
#                                          avg_salary
# Industry
# Security Services                        172.400000
# Telecommunications Manufacturing         146.375000
# Municipal Governments                    144.833333
# Enterprise Software & Network Solutions  123.250000
# Advertising & Marketing                  121.500000
# Telecommunications Services              116.500000
# Health Care Products Manufacturing       115.285714
# Federal Agencies                         114.700000
# Cable, Internet & Telephone Providers    111.475000
# Metals Brokers                           109.000000
# Lending                                  108.500000
# Computer Hardware & Software             106.781250
# Research & Development                   105.650000
# Aerospace & Defense                      102.391304
# IT Services                              102.384615
# Electrical & Electronic Manufacturing    102.291667
# Consulting                               101.907895
# Banks & Credit Unions                    100.590909
# Consumer Products Manufacturing           99.523810
# Insurance Carriers                        95.357143
# Utilities                                 93.732143
# Consumer Product Rental                   92.000000
# Energy                                    91.800000
# Biotech & Pharmaceuticals                 90.333333
# Insurance Agencies & Brokerages           89.000000
# Health Care Services & Hospitals          87.312500
# Transportation Equipment Manufacturing    86.500000
# Architectural & Engineering Services      86.086207
# Real Estate                               85.361111
# -1                                        84.874359
# Staffing & Outsourcing                    84.625000
# Wholesale                                 84.500000
# Metal & Mineral Manufacturing             80.950000
# Miscellaneous Manufacturing               80.100000
# Health, Beauty, & Fitness                 79.166667
# Financial Analytics & Research            78.500000
# Wood Product Manufacturing                75.000000
# Construction                              74.281250
# Industrial Manufacturing                  71.569444
# Membership Organizations                  67.000000
# Music Production & Distribution           66.500000
# Food & Beverage Manufacturing             65.937500
# Financial Transaction Processing          64.500000
# Business Service Centers & Copy Shops     55.500000
#
#
#
#                                     avg_salary
# Sector
# Government                          119.722222
# Telecommunications                  117.112903
# Mining & Metals                     109.000000
# Information Technology              106.660156
# Aerospace & Defense                 102.391304
# Finance                              97.766667
# Business Services                    95.428994
# Insurance                            94.562500
# Oil, Gas, Energy & Utilities         93.058140
# Biotech & Pharmaceuticals            90.333333
# Manufacturing                        90.289634
# Health Care                          87.312500
# Real Estate                          85.361111
# -1                                   84.874359
# Consumer Services                    84.300000
# Construction, Repair & Maintenance   74.281250
# Media                                66.500000
#
#
#
#                                   avg_salary
# Revenue
# $10+ billion (USD)                112.677273
# -1                                109.000000
# Less than $1 million (USD)        104.000000
# $1 to $2 billion (USD)            103.884615
# $10 to $25 million (USD)          103.233333
# $2 to $5 billion (USD)            101.125000
# $5 to $10 million (USD)            99.963636
# $25 to $50 million (USD)           97.588889
# $100 to $500 million (USD)         97.006494
# $500 million to $1 billion (USD)   89.314286
# Unknown / Non-Applicable           88.448276
# $5 to $10 billion (USD)            85.577778
# $1 to $5 million (USD)             84.153846
# $50 to $100 million (USD)          79.118056
#
#
#
#         avg_salary
# python
# 1       110.175676
# 0        94.209104
#
#
#
#         avg_salary
# matlab
# 1       102.875000
# 0        95.828773
#
#
#
#      avg_salary
# cpp
# 1    106.000000
# 0     95.175546
#
#
#
#      avg_salary
# dsp
# 1    107.490385
# 0     95.692867
#
#
#
#        avg_salary
# power
# 0       97.404822
# 1       95.535142
#
#
#
#                  avg_salary
# Embedded_System
# 1                110.319588
# 0                 94.515497
#
#
#
#     avg_salary
# ML
# 1   105.968750
# 0    96.279869
#
#
#
#                  avg_salary
# Num_Competitors
# 3                103.197561
# 2                 97.040230
# 0                 93.871706
# 1                 88.978261
# 4                 80.833333

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns ='python', values ='avg_salary', aggfunc = 'count')
# Out:
# python                                0     1
# Revenue
# $1 to $2 billion (USD)             58.0  20.0
# $1 to $5 million (USD)             13.0   NaN
# $10 to $25 million (USD)           25.0   5.0
# $10+ billion (USD)                 71.0  39.0
# $100 to $500 million (USD)        141.0  13.0
# $2 to $5 billion (USD)             55.0  13.0
# $25 to $50 million (USD)           40.0   5.0
# $5 to $10 billion (USD)            39.0   6.0
# $5 to $10 million (USD)            10.0   1.0
# $50 to $100 million (USD)          72.0   NaN
# $500 million to $1 billion (USD)   31.0   4.0
# -1                                  1.0   NaN
# Less than $1 million (USD)          2.0   1.0
# Unknown / Non-Applicable          112.0   4.0

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow()
#plt.imshow(interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-277-293c574ce86d> in <module>
#      20
#      21 plt.figure(figsize=[10,10])
# ---> 22 plt.imshow()
#      23 #plt.imshow(interpolation="bilinear")
#      24 plt.axis('off')
#
# TypeError: imshow() missing 1 required positional argument: 'X'
